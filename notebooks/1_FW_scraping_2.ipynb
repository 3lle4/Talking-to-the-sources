# %% [markdown]
# # Notebook: Scraping of the N.S. Frauen-Warte and export to CSV

# %% [markdown]
# To scrape the *Frauen-Warte*, input the `year_number` in the format, as well as `start_page` and `end_page` as a number (without leading zeros).
#
# For the available years and numbers of the respective page see here: https://digi.ub.uni-heidelberg.de/diglit/frauenwarte

# %%
#@title 0. Enter Parameters
year_number = 'frauenwarte1944' #@param {type:"string"}
start_page =  1 #@param {type:"integer"}
end_page = 44 #@param {type:"integer"}

# %% [markdown]
# ## 1. Install and import required libraries

# %%
# !pip install requests beautifulsoup4
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.31.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (4.12.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.2.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4) (2.5)

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ## 2. Function to fetch and parse webpage

# %%
def scrape_page(page_number):
    url = f"https://digi.ub.uni-heidelberg.de/diglit/{year_number}/{page_number}/image,info,text_ocr#col_text_ocr"
    response = requests.get(url)
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')

        # Extract page number text
        page_num_element = soup.find('li', class_='navbar-text ml-4')
        page_num_text = page_num_element.find('div', class_='badge badge-secondary').text if page_num_element else 'Page number not found'

        # Extract OCR text
        ocr_text_element = soup.find(id='column_text_ocr')
        ocr_texts = ocr_text_element.find_all(class_='text_part') if ocr_text_element else []
        ocr_text = ' '.join([text.get_text(strip=True) for text in ocr_texts])

        return page_num_text, ocr_text
    else:
        return 'Failed to fetch page', ''

# %% [markdown]
# ## 3. Iterate through page numbers and collect data

# %%
page_numbers = range(start_page, end_page)

# dictionary to store the results, with page numbers as keys
results = {}

for number in page_numbers:
    formatted_number = f"{number:04d}"  # Format number to 4 digits with leading zeros
    page_text, ocr_text = scrape_page(formatted_number)
    results[formatted_number] = {'page_text': page_text, 'ocr_text': ocr_text}

    # print the progress
    print(f"Scraped page {formatted_number}")
# Out:
# Scraped page 0001
# Scraped page 0002
# Scraped page 0003
# Scraped page 0004
# Scraped page 0005
# Scraped page 0006
# Scraped page 0007
# Scraped page 0008
# Scraped page 0009
# Scraped page 0010
# Scraped page 0011
# Scraped page 0012
# Scraped page 0013
# Scraped page 0014
# Scraped page 0015
# Scraped page 0016
# Scraped page 0017
# Scraped page 0018
# Scraped page 0019
# Scraped page 0020
# Scraped page 0021
# Scraped page 0022
# Scraped page 0023
# Scraped page 0024
# Scraped page 0025
# Scraped page 0026
# Scraped page 0027
# Scraped page 0028
# Scraped page 0029
# Scraped page 0030
# Scraped page 0031
# Scraped page 0032
# Scraped page 0033
# Scraped page 0034
# Scraped page 0035
# Scraped page 0036
# Scraped page 0037
# Scraped page 0038
# Scraped page 0039
# Scraped page 0040
# Scraped page 0041
# Scraped page 0042
# Scraped page 0043

# %% [markdown]
# ## 4. Save and download scraped data

# %%
import pandas as pd

df = pd.DataFrame.from_dict(results, orient='index')

# %%
df
# Out:
#       page_text                                           ocr_text
# 0001   Seite: 1  srauen-Varktc! i s e i n 2: i g e p 3 ^ t 6 i ...
# 0002   Seite: 2  All«s Schwe« viklitrt «n Btixutung, wtnn Aeir ...
# 0003   Seite: 3  Ois Ssrictitsr clsc fcsusn isigsc, I.isbs unci...
# 0004   Seite: 4  Am Tage ror der Begebenhei« waren wir auf unse...
# 0005   Seite: 5  LIHL LL2lllI-v^6 LV8 VLLl X06L6LLILI VO^ U-ö. ...
# 0006   Seite: 6  kot ^nrpruct, ouf «ien kiausarbsilrlog?2)ie Fr...
# 0007   Seite: 7  pcreirlX vno^«xt«I!« : 5ur« 8«»kk»ff. ^s^ckt««...
# 0008   Seite: 8  4-9157 V 4S119^tt 49149 49159 V 1451Vin durchg...
# 0009   Seite: 9  Dar flvircknkmalr irt unr in «Ivr Irucr«n 2«il...
# 0010  Seite: 10  2»ln Bau einrr provisorischen Feurrstelle werd...
# 0011  Seite: 11  Blutotröpflein tForts-tzun, voi, s-it« r)Da ve...
# 0012  Seite: 12  okrkic«»«kr vox k»«oki5c«k»i «>»iii»lLiviki5rk...
# 0013  Seite: 13  srauen Varktciis einrige psstsismllicsis ffsue...
# 0014  Seite: 14  Älanch« Fra« fragt in Stundrn, die hrute keina...
# 0015  Seite: 15  llsd daou dü imLrrv, VLtrr odrr öattr»,Sir la-...
# 0016  Seite: 16  ?»»v Oruncl: >e-ca>nNsu- imAtin« K»nst «ird na...
# 0017  Seite: 17  wisder autbcluenfrst gemrg gebaut ist, Iahrzeh...
# 0018  Seite: 18  'MW"—''»olle» «» sehr Le«ühe», asch ür diefesr...
# 0019  Seite: 19  Kurj einr« Holzschuh wird das dleiae öchiff ge...
# 0020  Seite: 20  I»15> X 5ehr Myevd licb wrrkt das Ls-ge»iLeid ...
# 0021  Seite: 21  1 kliv einon Rest PlLsch oder anderenr Materia...
# 0022  Seite: 22  Aeichrsurgo»: NeMrr915» VMrt yilfe dieser Schr...
# 0023  Seite: 23  »»kvkL xvirr skKßcttrerWerkehrendirnst a»ch k»...
# 0024  Seite: 24  /ü> c^o/c/s/e/r/L'/» kass«» gerirboc«, leicht ...
# 0025  Seite: 25  Orsuts OrtwaiciTlrotz Kampf, Krieg und^sod ble...
# 0026  Seite: 26  Da» SchicksalDirSmal ab«r: Wievielen »on euch ...
# 0027  Seite: 27  - Hlkct mv -KmenMcs mch liiiich allc jchvmMr's...
# 0028  Seite: 28  In »cc«mt,«c>.ztatn : U OrtM»I«jNrztes, waÄ er...
# 0029  Seite: 29  ^chon in den letzten Iahren vor dem Kriege hat...
# 0030  Seite: 30  ' ^ 'gf-lchlHrimscr-ßichn nmd ckl liaiMÄ^MNnu^...
# 0031  Seite: 31  z»r Hälfte nach der Vdersertr .... »rnd zweima...
# 0032  Seite: 32  Tin schlichtcs einfarbiges Kleid ka»» durch ci...
# 0033  Seite: 33  Zingeransatz sür Fingerha»Lsch«ö« oder für Fäi...
# 0034  Seite: 34  »Ws» S5 niLkt S»S5 gidl...?'„Groß« Pleite! Kci...
# 0035  Seite: 35  8si«juny, Verpileyuny uncj IsLctienye><j. ^ur-...
# 0036  Seite: 36  tterrkstter Xsr1o««I1op<l -1'/, t-x Kartoffeln...
# 0037  Seite: 37  srauen-Vartcc! i 6 sinrlgs p 3 >-t 6 i s m t I...
# 0038  Seite: 38  geran, wns >n lyrer slaqr lag: oen ^iegln seln...
# 0039  Seite: 39  Zukunst wird der verstärkte Zraueneinsah inner...
# 0040  Seite: 40  wlkD«e Süuee«»können Sradrleure beim Bauer bei...
# 0041  Seite: 41  vorüitste Vsützkupps, btserestticti-KsetottsIn...
# 0042  Seite: 42  roll msn nl«t»1 «I ur«t»gr«it»nlSkwitz, man lo...
# 0043  Seite: 43  vis !trsu6o5s dskomml sin ksnRlsriStreudoscn f...

# %%
from google.colab import files

df_name = f"{year_number}.csv"

df.to_csv(df_name)
files.download(df_name)
